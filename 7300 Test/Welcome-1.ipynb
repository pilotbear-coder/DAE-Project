# %% [markdown]
# # Practice
# ## Copy Code
# ###    1. Copy the code you see below (the 2 print statements in the grey box) and paste it into the blank grey box below it.
# ###    2. In your new code, replace the xx with your name.
# ## Add New Code
# ###    3. Add a third line. A new print statement using the same format as the 2 previous lines of code to tell the world something else about you. (Maybe where you live or how many pets you have.)
# ## Run Code
# ###    4. Run your code by clicking on "Run" and then "Run Selected Cell" (or you could also select "Run All Cells")
# ###    5. Make a couple of changes either to the starter code or to your code and then play with a couple of the other selections under "Run" to see what they do.
# ## Save
# ###    6. Save your code by either clicking on the save icon or by clicking on "Save Notebook" in the "File" dropdown.

# %%
print("hello world")
print("my name is xx")
